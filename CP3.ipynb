# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoVergani/Analise_energy_consuption/blob/main/CP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


import pandas as pd
import pprint

import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
def Custom_Ax(ax, ylabel_name='', ylabel_size=16, xlabel_name='', xlabel_size=16):
    ax.set_ylabel(ylabel_name, fontdict={'fontsize': ylabel_size})
    ax.set_xlabel(xlabel_name, fontdict={'fontsize': xlabel_size})
    ax.grid(color='black', linestyle='-', linewidth=1, alpha=.5)
    ax.grid(which='minor', axis="x", color="black", alpha=.2, linewidth=.5, linestyle="--")
    ax.grid(which='minor', axis="y", color="black", alpha=.2, linewidth=.5, linestyle="--")
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.grid(visible=True, which='major', axis="x", color="black", alpha=1, linewidth=.5, linestyle="-")
    ax.grid(visible=True, which='major', axis="y", color="black", alpha=1, linewidth=.5, linestyle="-")

    return ax

# %%
df = pd.read_csv("world_energy_consumption.csv")

# %%
df.head(100)
# Out:
#           country  year iso_code  population           gdp  \
# 0   ASEAN (Ember)  2000      NaN         NaN           NaN
# 1   ASEAN (Ember)  2001      NaN         NaN           NaN
# 2   ASEAN (Ember)  2002      NaN         NaN           NaN
# 3   ASEAN (Ember)  2003      NaN         NaN           NaN
# 4   ASEAN (Ember)  2004      NaN         NaN           NaN
# ..            ...   ...      ...         ...           ...
# 95    Afghanistan  1972      AFG  11286753.0  1.317055e+10
# 96    Afghanistan  1973      AFG  11575308.0  1.356863e+10
# 97    Afghanistan  1974      AFG  11869881.0  1.430911e+10
# 98    Afghanistan  1975      AFG  12157390.0  1.517777e+10
# 99    Afghanistan  1976      AFG  12425276.0  1.602361e+10
#
#     biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# ..                      ...                      ...                      ...
# 95                      NaN                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
# 97                      NaN                      NaN                      NaN
# 98                      NaN                      NaN                      NaN
# 99                      NaN                      NaN                      NaN
#
#     biofuel_consumption  biofuel_elec_per_capita  ...  solar_share_elec  \
# 0                   NaN                      NaN  ...               0.0
# 1                   NaN                      NaN  ...               0.0
# 2                   NaN                      NaN  ...               0.0
# 3                   NaN                      NaN  ...               0.0
# 4                   NaN                      NaN  ...               0.0
# ..                  ...                      ...  ...               ...
# 95                  NaN                      NaN  ...               NaN
# 96                  NaN                      NaN  ...               NaN
# 97                  NaN                      NaN  ...               NaN
# 98                  NaN                      NaN  ...               NaN
# 99                  NaN                      NaN  ...               NaN
#
#     solar_share_energy  wind_cons_change_pct  wind_cons_change_twh  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
# 3                  NaN                   NaN                   NaN
# 4                  NaN                   NaN                   NaN
# ..                 ...                   ...                   ...
# 95                 NaN                   NaN                   NaN
# 96                 NaN                   NaN                   NaN
# 97                 NaN                   NaN                   NaN
# 98                 NaN                   NaN                   NaN
# 99                 NaN                   NaN                   NaN
#
#     wind_consumption  wind_elec_per_capita  wind_electricity  \
# 0                NaN                   NaN               0.0
# 1                NaN                   NaN               0.0
# 2                NaN                   NaN               0.0
# 3                NaN                   NaN               0.0
# 4                NaN                   NaN               0.0
# ..               ...                   ...               ...
# 95               NaN                   NaN               NaN
# 96               NaN                   NaN               NaN
# 97               NaN                   NaN               NaN
# 98               NaN                   NaN               NaN
# 99               NaN                   NaN               NaN
#
#     wind_energy_per_capita  wind_share_elec  wind_share_energy
# 0                      NaN              0.0                NaN
# 1                      NaN              0.0                NaN
# 2                      NaN              0.0                NaN
# 3                      NaN              0.0                NaN
# 4                      NaN              0.0                NaN
# ..                     ...              ...                ...
# 95                     NaN              NaN                NaN
# 96                     NaN              NaN                NaN
# 97                     NaN              NaN                NaN
# 98                     NaN              NaN                NaN
# 99                     NaN              NaN                NaN
#
# [100 rows x 129 columns]

# %%
df[df.country=='Brazil']
# Out:
#      country  year iso_code   population           gdp  \
# 2853  Brazil  1900      BRA   18058538.0  1.571802e+10
# 2854  Brazil  1901      BRA   18463951.0  1.728848e+10
# 2855  Brazil  1902      BRA   18869255.0  1.729822e+10
# 2856  Brazil  1903      BRA   19274237.0  1.764560e+10
# 2857  Brazil  1904      BRA   19687910.0  1.798087e+10
# ...      ...   ...      ...          ...           ...
# 2971  Brazil  2018      BRA  210166592.0  2.965402e+12
# 2972  Brazil  2019      BRA  211782880.0           NaN
# 2973  Brazil  2020      BRA  213196304.0           NaN
# 2974  Brazil  2021      BRA  214326224.0           NaN
# 2975  Brazil  2022      BRA  215313504.0           NaN
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 2853                      NaN                      NaN
# 2854                      NaN                      NaN
# 2855                      NaN                      NaN
# 2856                      NaN                      NaN
# 2857                      NaN                      NaN
# ...                       ...                      ...
# 2971                   15.988                   32.936
# 2972                   10.687                   25.537
# 2973                   -6.896                  -18.240
# 2974                   -1.120                   -2.757
# 2975                   -0.631                   -1.535
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 2853                      NaN                  NaN                      NaN
# 2854                      NaN                  NaN                      NaN
# 2855                      NaN                  NaN                      NaN
# 2856                      NaN                  NaN                      NaN
# 2857                      NaN                  NaN                      NaN
# ...                       ...                  ...                      ...
# 2971                 1136.938              238.946                  248.041
# 2972                 1248.842              264.483                  248.793
# 2973                 1155.008              246.243                  265.295
# 2974                 1136.055              243.486                  268.749
# 2975                 1123.715              241.951                  266.681
#
#       ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 2853  ...               NaN                 NaN                   NaN
# 2854  ...               NaN                 NaN                   NaN
# 2855  ...               NaN                 NaN                   NaN
# 2856  ...               NaN                 NaN                   NaN
# 2857  ...               NaN                 NaN                   NaN
# ...   ...               ...                 ...                   ...
# 2971  ...             0.579               0.263                14.400
# 2972  ...             1.065               0.497                15.493
# 2973  ...             1.732               0.832                 1.902
# 2974  ...             2.528               1.228                26.705
# 2975  ...             3.889               2.109                12.929
#
#       wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 2853                   NaN               NaN                   NaN
# 2854                   NaN               NaN                   NaN
# 2855                   NaN               NaN                   NaN
# 2856                   NaN               NaN                   NaN
# 2857                   NaN               NaN                   NaN
# ...                    ...               ...                   ...
# 2971                15.484           128.252               228.961
# 2972                19.325           147.577               261.730
# 2973                 2.255           149.832               264.920
# 2974                39.317           189.149               333.604
# 2975                23.675           212.824               371.551
#
#       wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 2853               NaN                     NaN              NaN
# 2854               NaN                     NaN              NaN
# 2855               NaN                     NaN              NaN
# 2856               NaN                     NaN              NaN
# 2857               NaN                     NaN              NaN
# ...                ...                     ...              ...
# 2971             48.12                 610.240            8.099
# 2972             55.43                 696.829            8.960
# 2973             56.48                 702.787            9.193
# 2974             71.50                 882.529           10.791
# 2975             80.00                 988.440           11.750
#
#       wind_share_energy
# 2853                NaN
# 2854                NaN
# 2855                NaN
# 2856                NaN
# 2857                NaN
# ...                 ...
# 2971              3.690
# 2972              4.177
# 2973              4.414
# 2974              5.297
# 2975              5.714
#
# [123 rows x 129 columns]

# %%
df['biofuel_electricity_%'] = df['biofuel_electricity'] / df['electricity_generation']
df['coal_electricity_%'] = df['coal_electricity'] / df['electricity_generation']
df['fossil_electricity_%'] = df['fossil_electricity'] / df['electricity_generation']
df['gas_electricity_%'] = df['gas_electricity'] / df['electricity_generation']
df['hydro_electricity_%'] = df['hydro_electricity'] / df['electricity_generation']
df['nuclear_electricity_%'] = df['nuclear_electricity'] / df['electricity_generation']
df['oil_electricity_%'] = df['oil_electricity'] / df['electricity_generation']
df['solar_electricity_%'] = df['solar_electricity'] / df['electricity_generation']
df['wind_electricity_%'] = df['wind_electricity'] / df['electricity_generation']
df['renewables_electricity_%'] = df['renewables_electricity'] / df['electricity_generation']
df['other_renewable_electricity_%'] = df['other_renewable_electricity'] / df['electricity_generation']
df['other_renewable_exc_biofuel_electricity_%'] = df['other_renewable_exc_biofuel_electricity'] / df['electricity_generation']

# %%
fig, ax = plt.subplots()

ax = Custom_Ax(ax, xlabel_size=12)

ax.set(xticks=(df.year[(df['year'] >= 2000) & (df['year'] <= 2022)].unique()))

df[(df['year'] >= 2000) & (df['year'] <= 2022)].groupby(['year']).sum().plot(kind='line', ylabel='TWh' ,y=['electricity_generation','biofuel_electricity','coal_electricity','fossil_electricity',
'gas_electricity','hydro_electricity','nuclear_electricity','oil_electricity','other_renewable_electricity','other_renewable_exc_biofuel_electricity'],
ax=ax, title='Electricity - WorldWide', grid=True, figsize=(16,8)).legend(bbox_to_anchor=(1.0, 1.0))

# %%
plt.rcParams.update({'figure.max_open_warning': 0})

df_renewables = df[df['year'] == 2022]

print('TOP Countrys in 2022:')
for n in df_renewables.sort_values(by=['renewables_electricity_%'],ascending=False)['country'][:5]:
  print(n)

for n in df_renewables.sort_values(by=['renewables_electricity_%'],ascending=False)['country'][:5]:
  fig, ax = plt.subplots()

  ax.set(xticks=(df.year[(df['year'] >= 2000) & (df['year'] <= 2022)].unique()))

  ax = Custom_Ax(ax, xlabel_size=12)

  df[(df.country==n) & (df['year'] >= 2000) & (df['year'] <= 2022)].plot(kind='line', x='year', ylabel='%', y=['biofuel_electricity_%','fossil_electricity_%',
  'hydro_electricity_%','nuclear_electricity_%','other_renewable_electricity_%','other_renewable_exc_biofuel_electricity_%'],
  ax=ax, title='Electricity - '+n, grid=True, figsize=(16,8)).legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# TOP Countrys in 2022:
# Iceland
# Norway
# Costa Rica
# Kenya
# Brazil

# %%
df_renewables[['country','renewables_electricity_%']].sort_values(by=['renewables_electricity_%'],ascending=False)
# Out:
#            country  renewables_electricity_%
# 9165       Iceland                  0.999901
# 14590       Norway                  0.989717
# 4778    Costa Rica                  0.980206
# 10314        Kenya                  0.897810
# 2975        Brazil                  0.869404
# ...            ...                       ...
# 18232  South Sudan                       NaN
# 18514        Sudan                       NaN
# 19005        Syria                       NaN
# 21674        Yemen                       NaN
# 22011     Zimbabwe                       NaN
#
# [146 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mapeando os continentes
continent_map = {
    'Africa': ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo', 'Cote d\'Ivoire', 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
    'Asia': ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei Darussalam', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestine', 'Philippines', 'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'],
    'Europa': ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican City'],
    'America do Norte': ['Canada', 'Greenland', 'Mexico', 'United States'],
    'Oceania': ['Australia', 'Fiji', 'New Zealand', 'Papua New Guinea'],
    'America do Sul': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela']
}

# Filtrando
dataset_filtered = df[df['energy_per_capita'].notna()]

# Adicionando a coluna continente
dataset_filtered['continent'] = dataset_filtered['country'].map(lambda x: next((k for k, v in continent_map.items() if x in v), None))
dataset_filtered = dataset_filtered[dataset_filtered['continent'].notna()]

# Plotando
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=dataset_filtered, x='continent', y='energy_per_capita', ax=ax)
ax.set_title('Consumo de energia per capita por continente')
ax.set_xlabel('Continente')
ax.set_ylabel('Energia per Capita (units)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-b53449c0ffa0>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_filtered['continent'] = dataset_filtered['country'].map(lambda x: next((k for k, v in continent_map.items() if x in v), None))

# %%
fig, ax = plt.subplots(figsize=(10, 6))
source_cols = ['coal_consumption', 'gas_consumption', 'oil_consumption', 'renewables_consumption', 'nuclear_consumption']
df[source_cols].sum().plot(kind='pie', ax=ax, autopct='%1.1f%%')
ax.set_title('Tipos de energia usada')
ax.set_ylabel('')
plt.tight_layout()

# %%
# Plotando consumo de energia vs. emissoes de CO2
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=df, x='energy_per_capita', y='greenhouse_gas_emissions', ax=ax)
ax.set_title('Consumo de energia vs. CO2')
ax.set_xlabel('Consumo de energia per capita')
ax.set_ylabel('CO2')
plt.tight_layout()
